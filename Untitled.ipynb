# %%
import sklearn 
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df_1 = pd.read_csv("/Users/sebinsimon/Computing Project/Dataset/BRCA.csv")
df_2 = pd.read_csv("/Users/sebinsimon/Computing Project/Dataset/Breast Cancer Data.csv")
df_3 = pd.read_csv("/Users/sebinsimon/Computing Project/Dataset/Breast_Cancer.csv")
df_4 = pd.read_csv("/Users/sebinsimon/Computing Project/Dataset/NKI_cleaned.csv")
df_5 = pd.read_csv("/Users/sebinsimon/Computing Project/Dataset/bcr.csv")

# %%
df_1.head()
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# ...

# %%
df_2.head()
# Out:
#    Unnamed: 0 diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           0         M        17.99         10.38          122.80     1001.0
# 1           1         M        20.57         17.77          132.90     1326.0
# 2           2         M        19.69         21.25          130.00     1203.0
# 3           3         M        11.42         20.38           77.58      386.1
# 4           4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df_1.head()
